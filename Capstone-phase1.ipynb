# %% [markdown]
# # Phase 1

# %% [markdown]
# I have collected the below data from two places and club those together in one file
#
# 1. https://www.kaggle.com/datasets/gokulrajkmv/indian-statewise-data-from-rbi
# 2. https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_area
#
# these are two sites from where I gatheres data

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('C://Users//ASHTABHUJA//Downloads//cluster.csv')
data
# Out:
#        States_Union Territories  2000-01-INC  2011-12-INC  2001 - LIT  \
# 0   Andaman and Nicobar Islands      25047.0      89642.0       81.30
# 1                Andhra Pradesh      17195.0      64773.0       60.47
# 2             Arunachal Pradesh      15260.0      71366.0       54.34
# 3                         Assam      12803.0      36320.0       63.25
# 4                         Bihar       6415.0      22582.0       47.00
# 5                    Chandigarh      49771.0     136883.0       81.94
# 6                  Chhattisgarh      10744.0      48366.0       64.66
# 7                         Delhi      40678.0     161446.0       57.63
# 8                           Goa      43735.0     211570.0       78.18
# 9                       Gujarat      18392.0      85979.0       81.67
# 10                      Haryana      25583.0     106320.0       82.01
# 11             Himachal Pradesh      22795.0      75185.0       69.14
# ...

# %% [markdown]
# 1. The population of each state.

# %%
data['2001 - POP']
# Out:
# 0        356.0
# 1      76210.0
# 2       1098.0
# 3      26656.0
# 4      82999.0
# 5        901.0
# 6      20834.0
# 7      13851.0
# 8       1348.0
# 9      50671.0
# 10     21145.0
# 11      6078.0
# 12     10144.0
# 13     26946.0
# 14     52851.0
# 15     31841.0
# 16     60348.0
# 17     96879.0
# 18      2294.0
# 19      2319.0
# 20       889.0
# 21      1990.0
# 22     36805.0
# 23       974.0
# 24     24359.0
# 25     56507.0
# 26       541.0
# 27     62406.0
# 28      3199.0
# 29    166198.0
# 30      8489.0
# 31     80176.0
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# Name: 2001 - POP, dtype: float64

# %% [markdown]
# 2. Literacy Rate in each state

# %%
data['2001 - LIT']
# Out:
# 0     81.30
# 1     60.47
# 2     54.34
# 3     63.25
# 4     47.00
# 5     81.94
# 6     64.66
# 7     57.63
# 8     78.18
# 9     81.67
# 10    82.01
# 11    69.14
# 12    67.91
# 13    76.48
# 14    55.52
# 15    53.56
# 16    66.60
# 17    90.86
# 18    86.66
# 19    63.74
# 20    76.88
# 21    70.50
# 22    62.56
# 23    88.80
# 24    66.59
# 25    63.08
# 26    81.24
# 27    69.65
# 28    68.81
# 29    73.45
# 30    73.19
# 31    56.27
# 32      NaN
# 33      NaN
# 34      NaN
# 35      NaN
# 36      NaN
# 37      NaN
# 38      NaN
# Name: 2001 - LIT, dtype: float64

# %% [markdown]
# 3. Area of each state

# %%
data['Area (km2)']
# Out:
# 0           NaN
# 1      3,42,239
# 2      3,08,252
# 3      3,07,713
# 4      2,40,928
# 5      1,96,024
# 6      1,91,791
# 7      1,62,975
# 8      1,55,707
# 9      1,35,192
# 10     1,30,058
# 11     1,12,077
# 12       94,163
# 13       88,752
# 14       83,743
# 15       79,716
# 16       78,438
# 17       59,146
# 18    -1,66,698
# 19       55,673
# 20       53,483
# 21       50,362
# 22       44,212
# 23       42,241
# 24      -55,538
# 25       38,863
# 26       22,429
# 27       22,327
# 28       21,081
# 29       16,579
# 30       10,491
# 31        8,249
# 32        7,096
# 33        3,702
# 34        1,484
# 35          603
# 36          479
# 37          114
# 38           32
# Name: Area (km2), dtype: object
