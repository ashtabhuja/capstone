# %% [markdown]
# # Phase 2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('C://Users//ASHTABHUJA//Downloads//Phase2.csv')
df1
# Out:
#             STATE/UT  TOTAL IPC CRIMES  2001 - LIT Area (km2)  \
# 0     ANDHRA PRADESH              4154       81.30        NaN
# 1     ANDHRA PRADESH              4125       60.47   3,42,239
# 2     ANDHRA PRADESH              5818       54.34   3,08,252
# 3     ANDHRA PRADESH              3140       63.25   3,07,713
# 4     ANDHRA PRADESH              6507       47.00   2,40,928
# ...              ...               ...         ...        ...
# 9012     LAKSHADWEEP                60         NaN        NaN
# 9013     LAKSHADWEEP                60         NaN        NaN
# 9014      PUDUCHERRY               787         NaN        NaN
# 9015      PUDUCHERRY              3494         NaN        NaN
# 9016      PUDUCHERRY              4281         NaN        NaN
#
#       OTHER IPC CRIMES  2001 - POP  YEAR
# 0                 1518       356.0  2001
# 1                  754     76210.0  2001
# 2                 1262      1098.0  2001
# 3                 1181     26656.0  2001
# ...

# %% [markdown]
# 2.1	Analysis of Literacy Rate vs Total Crimes.

# %%
sns.lineplot(x='2001 - LIT',y='TOTAL IPC CRIMES',data=df1)
# Out:
# <Axes: xlabel='2001 - LIT', ylabel='TOTAL IPC CRIMES'>

# %% [markdown]
# 2.2	 Analysis of the type of crime vs each state vs Literacy rate.

# %%
sns.lineplot(x='STATE/UT',y='2001 - LIT',data=df1)
# Out:
# <Axes: xlabel='STATE/UT', ylabel='2001 - LIT'>

# %% [markdown]
# 2.3	Analysis of year-on-year total crime rate.

# %%
sns.scatterplot(x='YEAR',y='TOTAL IPC CRIMES',data=df1)
# Out:
# <Axes: xlabel='YEAR', ylabel='TOTAL IPC CRIMES'>

# %% [markdown]
# 2.4	 Analysis of area vs overall crime

# %%
sns.lineplot(y='Area (km2)',x='TOTAL IPC CRIMES',data=df1)
# Out:
# <Axes: xlabel='TOTAL IPC CRIMES', ylabel='Area (km2)'>

# %% [markdown]
# 2.5	 Analysis of Population vs overall Crime

# %%
sns.lineplot(x='2001 - POP',y='TOTAL IPC CRIMES',data=df1)
# Out:
# <Axes: xlabel='2001 - POP', ylabel='TOTAL IPC CRIMES'>

# %% [markdown]
# # Conclusion

# %% [markdown]
# From the above points we can conclude that the in each state the overall crime is increasing over the year
